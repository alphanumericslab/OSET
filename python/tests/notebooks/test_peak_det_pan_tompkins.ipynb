# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
from oset.ecg.peak_detection.peak_det_pan_tompkins import (
    peak_det_pan_tompkins,
)
from oset.generic.lp_filter import lp_filter_zero_phase

# %%
mat = scipy.io.loadmat("../../../datasets/sample-data/SampleECG1.mat")["data"][0]
f = 1
fc = 0.5
fs = 1000
t = np.arange(len(mat)) / fs
# mat = mat - lp_filter_zero_phase(mat, fc / fs)  # filter
peaks, peak_indexes = peak_det_pan_tompkins(mat, fs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       5 t = np.arange(len(mat)) / fs
#       6 # mat = mat - lp_filter_zero_phase(mat, fc / fs)  # filter
# ----> 7 peaks, peak_indexes = peak_det_pan_tompkins(mat, fs)
#
# File ~\anaconda3\Lib\site-packages\oset\ecg\peak_detection\peak_det_pan_tompkins.py:104, in peak_det_pan_tompkins(ecg_data, fs, ecg_polarity, qrs_width, refracT)
#      96 # remove delays & resample
#      97 integrated_data = np.concatenate(
#      98     (
#      99         integrated_data[total_delay:],
#    (...)
#     102     axis=0,
#     103 ).T
# --> 104 integrated_data = resample(integrated_data, int(fs / g), int(fs_pt / g))
#     105 integrated_data = integrated_data / np.std(integrated_data)
#     107 filtered_data = np.concatenate(
#     108     (
#     109         filtered_data[filter_delay:],
#    (...)
#     112     axis=0,
#     113 ).T
#
# File ~\anaconda3\Lib\site-packages\scipy\signal\_signaltools.py:3192, in resample(x, num, t, axis, window, domain)
#    3190     return y
#    3191 else:
# -> 3192     new_t = np.arange(0, num) * (t[1] - t[0]) * Nx / float(num) + t[0]
#    3193     return y, new_t
#
# TypeError: 'int' object is not subscriptable

# %%
plt.figure()
plt.figure(figsize=(12, 5))
plt.plot(t, mat, "b", label="ECG")
plt.plot(t[peak_indexes], mat[peak_indexes], "ro", label="ECG Peaks (max detection)")
plt.xlabel("time (sec.)")
plt.legend()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 plt.figure(figsize=(12, 5))
#       3 plt.plot(t, mat, "b", label="ECG")
# ----> 4 plt.plot(t[peak_indexes], mat[peak_indexes], "ro", label="ECG Peaks (max detection)")
#       5 plt.xlabel("time (sec.)")
#       6 plt.legend()
#
# NameError: name 'peak_indexes' is not defined
