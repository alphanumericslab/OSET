# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
from oset.generic.lp_filter.lp_filter_zero_phase import lp_filter_zero_phase
from oset.ecg.peak_detection.peak_detection_local_search import peak_detection_local_search

# %%
mat = scipy.io.loadmat('../../../datasets/sample-data/SampleECG1.mat')['data'][0]
f = 1
fc = 0.5
fs = 1000

mat = mat - lp_filter_zero_phase(mat, fc / fs)
peaks, peak_indexes = peak_detection_local_search(mat, f / fs)

# %%
t = np.arange(len(mat)) / fs

plt.figure()
plt.figure(figsize=(12, 5))
plt.plot(t, mat, 'b', label='ECG')
print(peak_indexes)
plt.plot(t[peak_indexes], mat[peak_indexes], 'ro', label='ECG Peaks (max detection)')
plt.xlabel('time (sec.)')
plt.legend()
plt.grid()
plt.show()
# Out:
# [  209  1054  1887  2695  3498  4301  5130  5971  6820  7662  8492  9304
#  10085 10857 11624 12403 13205 14031 14864 15698 16513 17319 18098 18872
#  19655]
