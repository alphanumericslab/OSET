# %%
import pandas as pd
import numpy as np
import os
from ComputeInputOutputDeltaSNRs import ComputeInputOutputDeltaSNRs

fs = 250

folder_name = "/../../../../ResultsComparison120s/"

csv_name = "CleanSignals"
repetition = 1
RawDataDF = pd.read_csv(
    os.getcwd() + folder_name + csv_name + str(repetition) + ".csv",
    header=0,
    index_col=0,
)
# ------------------------------------------------------------------------------------
deltaSNRMeanALL = pd.DataFrame()
deltaSNRVarALL = pd.DataFrame()
for noise_level in [-5, 0, 5, 10, 15, 20, 25, 30]:
    # ------------------------------------------------------------------------------------
    print("running for " + str(noise_level))
    # --------------
    repetition = 1
    # --------------
    csv_name = "NoisySignals" + str(noise_level) + "db_" + str(repetition)
    NoisyDataDFRep1 = pd.read_csv(
        os.getcwd() + folder_name + csv_name + ".csv", header=0, index_col=0
    )
    # --------------
    NoiseDFRep1 = NoisyDataDFRep1.subtract(RawDataDF)
    # --------------------------------------------------------
    csv_name = "GPFiltPost" + str(noise_level) + "db_" + str(repetition)
    GPFiltSigsPostDFRep1 = pd.read_csv(
        os.getcwd() + folder_name + csv_name + ".csv", header=0, index_col=0
    )
    csv_name = "GPFiltPrio" + str(noise_level) + "db_" + str(repetition)
    GPFiltSigsPrioDFRep1 = pd.read_csv(
        os.getcwd() + folder_name + csv_name + ".csv", header=0, index_col=0
    )
    # --------------------------------------------------------
    csv_name = "WaveFilt" + str(noise_level) + "db_" + str(repetition)
    WaveFiltDFRep1 = pd.read_csv(
        os.getcwd() + folder_name + csv_name + ".csv", header=None, index_col=0
    )
    # --------------------------------------------------------
    #     csv_name = 'RezaFiltPostGAUSSIAN' + str(noise_level) + 'db_' + str(repetition)
    #     RezaFiltPostDFRep1 = pd.read_csv(os.getcwd() + folder_name + csv_name + '.csv',
    #                                          header = None, index_col = 0)
    #     csv_name = 'RezaFiltPrioGAUSSIAN' + str(noise_level) + 'db_' + str(repetition)
    #     RezaFiltPrioDFRep1 = pd.read_csv(os.getcwd() + folder_name + csv_name + '.csv',
    #                                          header = None, index_col = 0)
    # ------------------------------------------------------------------------------------
    repetition = 2
    # --------------
    csv_name = "NoisySignals" + str(noise_level) + "db_" + str(repetition)
    NoisyDataDFRep2 = pd.read_csv(
        os.getcwd() + folder_name + csv_name + ".csv", header=0, index_col=0
    )
    # --------------
    NoiseDFRep2 = NoisyDataDFRep2.subtract(RawDataDF)
    # --------------------------------------------------------
    csv_name = "GPFiltPost" + str(noise_level) + "db_" + str(repetition)
    GPFiltSigsPostDFRep2 = pd.read_csv(
        os.getcwd() + folder_name + csv_name + ".csv", header=0, index_col=0
    )
    csv_name = "GPFiltPrio" + str(noise_level) + "db_" + str(repetition)
    GPFiltSigsPrioDFRep2 = pd.read_csv(
        os.getcwd() + folder_name + csv_name + ".csv", header=0, index_col=0
    )
    # --------------------------------------------------------
    csv_name = "WaveFilt" + str(noise_level) + "db_" + str(repetition)
    WaveFiltDFRep2 = pd.read_csv(
        os.getcwd() + folder_name + csv_name + ".csv", header=None, index_col=0
    )
    # --------------------------------------------------------
    #     csv_name = 'RezaFiltPostGAUSSIAN' + str(noise_level) + 'db_' + str(repetition)
    #     RezaFiltPostDFRep2 = pd.read_csv(os.getcwd() + folder_name + csv_name + '.csv',
    #                                          header = None, index_col = 0)
    #     csv_name = 'RezaFiltPrioGAUSSIAN' + str(noise_level) + 'db_' + str(repetition)
    #     RezaFiltPrioDFRep2 = pd.read_csv(os.getcwd() + folder_name + csv_name + '.csv',
    #                                          header = None, index_col = 0)
    # ------------------------------------------------------------------------------------
    repetition = 3
    # --------------
    csv_name = "NoisySignals" + str(noise_level) + "db_" + str(repetition)
    NoisyDataDFRep3 = pd.read_csv(
        os.getcwd() + folder_name + csv_name + ".csv", header=0, index_col=0
    )
    # --------------
    NoiseDFRep3 = NoisyDataDFRep3.subtract(RawDataDF)
    # --------------------------------------------------------
    csv_name = "GPFiltPost" + str(noise_level) + "db_" + str(repetition)
    GPFiltSigsPostDFRep3 = pd.read_csv(
        os.getcwd() + folder_name + csv_name + ".csv", header=0, index_col=0
    )
    csv_name = "GPFiltPrio" + str(noise_level) + "db_" + str(repetition)
    GPFiltSigsPrioDFRep3 = pd.read_csv(
        os.getcwd() + folder_name + csv_name + ".csv", header=0, index_col=0
    )
    # --------------------------------------------------------
    csv_name = "WaveFilt" + str(noise_level) + "db_" + str(repetition)
    WaveFiltDFRep3 = pd.read_csv(
        os.getcwd() + folder_name + csv_name + ".csv", header=None, index_col=0
    )
    # --------------------------------------------------------
    #     csv_name = 'RezaFiltPostGAUSSIAN' + str(noise_level) + 'db_' + str(repetition)
    #     RezaFiltPostDFRep3 = pd.read_csv(os.getcwd() + folder_name + csv_name + '.csv',
    #                                          header = None, index_col = 0)
    #     csv_name = 'RezaFiltPrioGAUSSIAN' + str(noise_level) + 'db_' + str(repetition)
    #     RezaFiltPrioDFRep3 = pd.read_csv(os.getcwd() + folder_name + csv_name + '.csv',
    #                                          header = None, index_col = 0)
    # ------------------------------------------------------------------------------------
    repetition = 4
    # --------------
    csv_name = "NoisySignals" + str(noise_level) + "db_" + str(repetition)
    NoisyDataDFRep4 = pd.read_csv(
        os.getcwd() + folder_name + csv_name + ".csv", header=0, index_col=0
    )
    # --------------
    NoiseDFRep4 = NoisyDataDFRep4.subtract(RawDataDF)
    # --------------------------------------------------------
    csv_name = "GPFiltPost" + str(noise_level) + "db_" + str(repetition)
    GPFiltSigsPostDFRep4 = pd.read_csv(
        os.getcwd() + folder_name + csv_name + ".csv", header=0, index_col=0
    )
    csv_name = "GPFiltPrio" + str(noise_level) + "db_" + str(repetition)
    GPFiltSigsPrioDFRep4 = pd.read_csv(
        os.getcwd() + folder_name + csv_name + ".csv", header=0, index_col=0
    )
    # --------------------------------------------------------
    csv_name = "WaveFilt" + str(noise_level) + "db_" + str(repetition)
    WaveFiltDFRep4 = pd.read_csv(
        os.getcwd() + folder_name + csv_name + ".csv", header=None, index_col=0
    )
    # --------------------------------------------------------
    #     csv_name = 'RezaFiltPostGAUSSIAN' + str(noise_level) + 'db_' + str(repetition)
    #     RezaFiltPostDFRep4 = pd.read_csv(os.getcwd() + folder_name + csv_name + '.csv',
    #                                          header = None, index_col = 0)
    #     csv_name = 'RezaFiltPrioGAUSSIAN' + str(noise_level) + 'db_' + str(repetition)
    #     RezaFiltPrioDFRep4 = pd.read_csv(os.getcwd() + folder_name + csv_name + '.csv',
    #                                          header = None, index_col = 0)
    # ------------------------------------------------------------------------------------
    repetition = 5
    # --------------
    csv_name = "NoisySignals" + str(noise_level) + "db_" + str(repetition)
    NoisyDataDFRep5 = pd.read_csv(
        os.getcwd() + folder_name + csv_name + ".csv", header=0, index_col=0
    )
    # --------------
    NoiseDFRep5 = NoisyDataDFRep5.subtract(RawDataDF)
    # --------------------------------------------------------
    csv_name = "GPFiltPost" + str(noise_level) + "db_" + str(repetition)
    GPFiltSigsPostDFRep5 = pd.read_csv(
        os.getcwd() + folder_name + csv_name + ".csv", header=0, index_col=0
    )
    csv_name = "GPFiltPrio" + str(noise_level) + "db_" + str(repetition)
    GPFiltSigsPrioDFRep5 = pd.read_csv(
        os.getcwd() + folder_name + csv_name + ".csv", header=0, index_col=0
    )
    # --------------------------------------------------------
    csv_name = "WaveFilt" + str(noise_level) + "db_" + str(repetition)
    WaveFiltDFRep5 = pd.read_csv(
        os.getcwd() + folder_name + csv_name + ".csv", header=None, index_col=0
    )
    # --------------------------------------------------------
    #     csv_name = 'RezaFiltPostGAUSSIAN' + str(noise_level) + 'db_' + str(repetition)
    #     RezaFiltPostDFRep5 = pd.read_csv(os.getcwd() + folder_name + csv_name + '.csv',
    #                                          header = None, index_col = 0)
    #     csv_name = 'RezaFiltPrioGAUSSIAN' + str(noise_level) + 'db_' + str(repetition)
    #     RezaFiltPrioDFRep5 = pd.read_csv(os.getcwd() + folder_name + csv_name + '.csv',
    #                                          header = None, index_col = 0)
    # ------------------------------------------------------------------------------------
    deltaSNRRep1 = pd.DataFrame()
    for i in np.arange(RawDataDF.shape[1]):
        deltaSNRGPPost = ComputeInputOutputDeltaSNRs(
            RawDataDF.iloc[:, i].dropna(),
            NoiseDFRep1.iloc[:, i].dropna(),
            GPFiltSigsPostDFRep1.iloc[:, i].dropna(),
        )[2]
        deltaSNRGPPrio = ComputeInputOutputDeltaSNRs(
            RawDataDF.iloc[:, i].dropna(),
            NoiseDFRep1.iloc[:, i].dropna(),
            GPFiltSigsPrioDFRep1.iloc[:, i].dropna(),
        )[2]
        # ------------------------------------------------------------------------------------
        deltaSNRWave = ComputeInputOutputDeltaSNRs(
            RawDataDF.iloc[:, i].dropna(),
            NoiseDFRep1.iloc[:, i].dropna(),
            WaveFiltDFRep1.iloc[:, i].dropna(),
        )[2]
        # ------------------------------------------------------------------------------------
        #         deltaSNRRezaPost = ComputeInputOutputDeltaSNRs(RawDataDF.iloc[:,i].dropna(),
        #                                                        NoiseDFRep1.iloc[:,i].dropna(),
        #                                                        RezaFiltPostDFRep1.iloc[:,i].dropna())[2]
        #         deltaSNRRezaPrio = ComputeInputOutputDeltaSNRs(RawDataDF.iloc[:,i].dropna(),
        #                                                        NoiseDFRep1.iloc[:,i].dropna(),
        #                                                        RezaFiltPrioDFRep1.iloc[:,i].dropna())[2]
        # ------------------------------------------------------------------------------------
        deltaSNRRep1[RawDataDF.columns[i]] = [
            deltaSNRGPPost,
            deltaSNRGPPrio,
            deltaSNRWave,  # ,deltaSNRRezaPost, deltaSNRRezaPrio
        ]
    # ------------------------------------------------------------------------------------
    deltaSNRRep2 = pd.DataFrame()
    for i in np.arange(RawDataDF.shape[1]):
        deltaSNRGPPost = ComputeInputOutputDeltaSNRs(
            RawDataDF.iloc[:, i].dropna(),
            NoiseDFRep2.iloc[:, i].dropna(),
            GPFiltSigsPostDFRep2.iloc[:, i].dropna(),
        )[2]
        deltaSNRGPPrio = ComputeInputOutputDeltaSNRs(
            RawDataDF.iloc[:, i].dropna(),
            NoiseDFRep2.iloc[:, i].dropna(),
            GPFiltSigsPrioDFRep2.iloc[:, i].dropna(),
        )[2]
        # ------------------------------------------------------------------------------------
        deltaSNRWave = ComputeInputOutputDeltaSNRs(
            RawDataDF.iloc[:, i].dropna(),
            NoiseDFRep2.iloc[:, i].dropna(),
            WaveFiltDFRep2.iloc[:, i].dropna(),
        )[2]
        # ------------------------------------------------------------------------------------
        #         deltaSNRRezaPost = ComputeInputOutputDeltaSNRs(RawDataDF.iloc[:,i].dropna(),
        #                                                        NoiseDFRep2.iloc[:,i].dropna(),
        #                                                        RezaFiltPostDFRep2.iloc[:,i].dropna())[2]
        #         deltaSNRRezaPrio = ComputeInputOutputDeltaSNRs(RawDataDF.iloc[:,i].dropna(),
        #                                                        NoiseDFRep2.iloc[:,i].dropna(),
        #                                                        RezaFiltPrioDFRep2.iloc[:,i].dropna())[2]
        # ------------------------------------------------------------------------------------
        deltaSNRRep2[RawDataDF.columns[i]] = [
            deltaSNRGPPost,
            deltaSNRGPPrio,
            deltaSNRWave,  # , deltaSNRRezaPost, deltaSNRRezaPrio
        ]
    # ------------------------------------------------------------------------------------
    deltaSNRRep3 = pd.DataFrame()
    for i in np.arange(RawDataDF.shape[1]):
        deltaSNRGPPost = ComputeInputOutputDeltaSNRs(
            RawDataDF.iloc[:, i].dropna(),
            NoiseDFRep3.iloc[:, i].dropna(),
            GPFiltSigsPostDFRep3.iloc[:, i].dropna(),
        )[2]
        deltaSNRGPPrio = ComputeInputOutputDeltaSNRs(
            RawDataDF.iloc[:, i].dropna(),
            NoiseDFRep3.iloc[:, i].dropna(),
            GPFiltSigsPrioDFRep3.iloc[:, i].dropna(),
        )[2]
        # ------------------------------------------------------------------------------------
        deltaSNRWave = ComputeInputOutputDeltaSNRs(
            RawDataDF.iloc[:, i].dropna(),
            NoiseDFRep3.iloc[:, i].dropna(),
            WaveFiltDFRep3.iloc[:, i].dropna(),
        )[2]
        # ------------------------------------------------------------------------------------
        #         deltaSNRRezaPost = ComputeInputOutputDeltaSNRs(RawDataDF.iloc[:,i].dropna(),
        #                                                        NoiseDFRep3.iloc[:,i].dropna(),
        #                                                        RezaFiltPostDFRep3.iloc[:,i].dropna())[2]
        #         deltaSNRRezaPrio = ComputeInputOutputDeltaSNRs(RawDataDF.iloc[:,i].dropna(),
        #                                                        NoiseDFRep3.iloc[:,i].dropna(),
        #                                                        RezaFiltPrioDFRep3.iloc[:,i].dropna())[2]
        # ------------------------------------------------------------------------------------
        deltaSNRRep3[RawDataDF.columns[i]] = [
            deltaSNRGPPost,
            deltaSNRGPPrio,
            deltaSNRWave,  # ,deltaSNRRezaPost, deltaSNRRezaPrio
        ]
    # ------------------------------------------------------------------------------------
    deltaSNRRep4 = pd.DataFrame()
    for i in np.arange(RawDataDF.shape[1]):
        deltaSNRGPPost = ComputeInputOutputDeltaSNRs(
            RawDataDF.iloc[:, i].dropna(),
            NoiseDFRep4.iloc[:, i].dropna(),
            GPFiltSigsPostDFRep4.iloc[:, i].dropna(),
        )[2]
        deltaSNRGPPrio = ComputeInputOutputDeltaSNRs(
            RawDataDF.iloc[:, i].dropna(),
            NoiseDFRep4.iloc[:, i].dropna(),
            GPFiltSigsPrioDFRep4.iloc[:, i].dropna(),
        )[2]
        # ------------------------------------------------------------------------------------
        deltaSNRWave = ComputeInputOutputDeltaSNRs(
            RawDataDF.iloc[:, i].dropna(),
            NoiseDFRep4.iloc[:, i].dropna(),
            WaveFiltDFRep4.iloc[:, i].dropna(),
        )[2]
        # ------------------------------------------------------------------------------------
        #         deltaSNRRezaPost = ComputeInputOutputDeltaSNRs(RawDataDF.iloc[:,i].dropna(),
        #                                                        NoiseDFRep4.iloc[:,i].dropna(),
        #                                                        RezaFiltPostDFRep4.iloc[:,i].dropna())[2]
        #         deltaSNRRezaPrio = ComputeInputOutputDeltaSNRs(RawDataDF.iloc[:,i].dropna(),
        #                                                        NoiseDFRep4.iloc[:,i].dropna(),
        #                                                        RezaFiltPrioDFRep4.iloc[:,i].dropna())[2]
        # ------------------------------------------------------------------------------------
        deltaSNRRep4[RawDataDF.columns[i]] = [
            deltaSNRGPPost,
            deltaSNRGPPrio,
            deltaSNRWave,  # , deltaSNRRezaPost, deltaSNRRezaPrio
        ]
    # ------------------------------------------------------------------------------------
    deltaSNRRep5 = pd.DataFrame()
    for i in np.arange(RawDataDF.shape[1]):
        deltaSNRGPPost = ComputeInputOutputDeltaSNRs(
            RawDataDF.iloc[:, i].dropna(),
            NoiseDFRep5.iloc[:, i].dropna(),
            GPFiltSigsPostDFRep5.iloc[:, i].dropna(),
        )[2]
        deltaSNRGPPrio = ComputeInputOutputDeltaSNRs(
            RawDataDF.iloc[:, i].dropna(),
            NoiseDFRep5.iloc[:, i].dropna(),
            GPFiltSigsPrioDFRep5.iloc[:, i].dropna(),
        )[2]
        # ------------------------------------------------------------------------------------
        deltaSNRWave = ComputeInputOutputDeltaSNRs(
            RawDataDF.iloc[:, i].dropna(),
            NoiseDFRep5.iloc[:, i].dropna(),
            WaveFiltDFRep5.iloc[:, i].dropna(),
        )[2]
        # ------------------------------------------------------------------------------------
        #         deltaSNRRezaPost = ComputeInputOutputDeltaSNRs(RawDataDF.iloc[:,i].dropna(),
        #                                                        NoiseDFRep5.iloc[:,i].dropna(),
        #                                                        RezaFiltPostDFRep5.iloc[:,i].dropna())[2]
        #         deltaSNRRezaPrio = ComputeInputOutputDeltaSNRs(RawDataDF.iloc[:,i].dropna(),
        #                                                        NoiseDFRep5.iloc[:,i].dropna(),
        #                                                        RezaFiltPrioDFRep5.iloc[:,i].dropna())[2]
        # ------------------------------------------------------------------------------------
        deltaSNRRep5[RawDataDF.columns[i]] = [
            deltaSNRGPPost,
            deltaSNRGPPrio,
            deltaSNRWave,  # , deltaSNRRezaPost, deltaSNRRezaPrio
        ]
    # ------------------------------------------------------------------------------------
    df = pd.concat(
        [deltaSNRRep1, deltaSNRRep2, deltaSNRRep3, deltaSNRRep4, deltaSNRRep5]
    )
    df.index.name = "index"

    deltaSNRMean = pd.DataFrame(df.groupby("index").mean().mean(axis=1))
    print(deltaSNRMean)
    deltaSNRMeanALL = pd.concat([deltaSNRMeanALL, deltaSNRMean], axis=1)
    print(deltaSNRMeanALL)

    deltaSNRVar = pd.DataFrame(df.groupby("index").mean().var(axis=1))
    print(deltaSNRVar)
    deltaSNRVarALL = pd.concat([deltaSNRVarALL, deltaSNRVar], axis=1)
    print(deltaSNRVarALL)
# Out:
# running for -5
# /opt/anaconda3/envs/env37/lib/python3.7/site-packages/ipykernel_launcher.py:171: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
# /opt/anaconda3/envs/env37/lib/python3.7/site-packages/ipykernel_launcher.py:195: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
# ...

# %%
deltaSNRMeanALL
# Out:
#                0          0         0         0         0         0  \
# index
# 0      14.658488  11.906724  9.103507  6.495731  4.194641  2.364496
# 1      14.846311  10.666010  5.977804  1.083606 -3.879821 -8.869427
# 2       8.551088   7.485417  6.372265  5.207222  3.940700  2.509455
#
#                0          0
# index
# 0       1.136732   0.464410
# 1     -13.865954 -18.864862
# 2       0.823317  -1.306711

# %%
target_file = os.getcwd() + "/../../../../ResultsComparison120s/FigsGP/"
fig_name = "SNRComparison"
target = [-5, 0, 5, 10, 15, 20, 25, 30]
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(18, 8))
ax = plt.subplot(1, 1, 1)
plt.grid()
plt.xlabel("Input SNR [dB]", fontsize=28)
plt.ylabel("SNR improvement [dB]", fontsize=28)
# ---------------------
# plt.errorbar(target, deltaSNRMeanALL.iloc[3,:] , np.sqrt(deltaSNRVarALL.iloc[3,:]),
#              solid_capstyle = 'butt', capsize=8,
#              linewidth = 6, label = 'reza')
# ---------------------
plt.errorbar(
    target,
    deltaSNRMeanALL.iloc[2, :],
    np.sqrt(deltaSNRVarALL.iloc[2, :]),
    solid_capstyle="butt",
    capsize=8,
    linewidth=6,
    label="Wavelet [benchmark]",
)
# ---------------------
plt.errorbar(
    target,
    deltaSNRMeanALL.iloc[1, :],
    np.sqrt(deltaSNRVarALL.iloc[1, :]),
    solid_capstyle="butt",
    capsize=8,
    linewidth=6,
    label="GP Prior ",
)
plt.errorbar(
    target,
    deltaSNRMeanALL.iloc[0, :],
    np.sqrt(deltaSNRVarALL.iloc[0, :]),
    solid_capstyle="butt",
    capsize=8,
    linewidth=6,
    label="GP Posterior",
)
# ---------------------
# plt.errorbar(target, deltaSNRMeanALL.iloc[4,:], np.sqrt(deltaSNRVarALL.iloc[1,:]),
#              solid_capstyle = 'butt', capsize=8,
#              linewidth = 6, label = 'GP Reza Prio')
# plt.errorbar(target, deltaSNRMeanALL.iloc[3,:], np.sqrt(deltaSNRVarALL.iloc[0,:]),
#              solid_capstyle = 'butt', capsize=8,
#              linewidth = 6, label = 'GP Reza Post')
# ---------------------
# plt.errorbar(target, deltaSNRMeanALL.iloc[5,:], np.sqrt(deltaSNRVarALL.iloc[1,:]),
#              solid_capstyle = 'butt', capsize=8,
#              linewidth = 6, label = 'GP Prio R')
# plt.errorbar(target, deltaSNRMeanALL.iloc[4,:], np.sqrt(deltaSNRVarALL.iloc[0,:]),
#              solid_capstyle = 'butt', capsize=8,
#              linewidth = 6, label = 'GP Post R')
# ---------------------
plt.yticks([-25, -20, -15, -10, -5, 0, 5, 10, 15, 20])
# plt.xticks([-10, -5, 0, 5, 10, 15, 20, 25, 30, 35])
plt.legend(fontsize=28, loc="lower left", ncol=3)
plt.xticks(fontsize=28, rotation=0)
plt.yticks(fontsize=28, rotation=0)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["bottom"].set_visible(True)
ax.spines["left"].set_visible(False)
fig.tight_layout()
plt.savefig(target_file + fig_name + ".eps", format="eps", bbox_inches="tight")
plt.savefig(target_file + fig_name + ".png", format="png", bbox_inches="tight")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
stp

# %%
fig_name = "SNRComparison"
target = [-5, 0, 5, 10, 15, 20, 25, 30]
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(18, 8))
ax = plt.subplot(1, 1, 1)
plt.grid()
plt.xlabel("Input SNR [dB]", fontsize=28)
plt.ylabel("SNR improvement [dB]", fontsize=28)
# ---------------------
# plt.errorbar(target, deltaSNRMeanALL.iloc[3,:] , np.sqrt(deltaSNRVarALL.iloc[3,:]),
#              solid_capstyle = 'butt', capsize=8,
#              linewidth = 6, label = 'reza')
# ---------------------
plt.errorbar(
    target,
    deltaSNRMeanALL.iloc[2, :],
    np.sqrt(deltaSNRVarALL.iloc[2, :]),
    solid_capstyle="butt",
    capsize=8,
    linewidth=6,
    label="Wavelet [benchmark]",
)
# ---------------------
plt.errorbar(
    target,
    deltaSNRMeanALL.iloc[1, :],
    np.sqrt(deltaSNRVarALL.iloc[1, :]),
    solid_capstyle="butt",
    capsize=8,
    linewidth=6,
    label="GP Prior ",
)
plt.errorbar(
    target,
    deltaSNRMeanALL.iloc[0, :],
    np.sqrt(deltaSNRVarALL.iloc[0, :]),
    solid_capstyle="butt",
    capsize=8,
    linewidth=6,
    label="GP Posterior",
)
# ---------------------
# plt.errorbar(target, deltaSNRMeanALL.iloc[3,:], np.sqrt(deltaSNRVarALL.iloc[1,:]),
#              solid_capstyle = 'butt', capsize=8,
#              linewidth = 6, label = 'GP Reza Prio')
# plt.errorbar(target, deltaSNRMeanALL.iloc[4,:], np.sqrt(deltaSNRVarALL.iloc[0,:]),
#              solid_capstyle = 'butt', capsize=8,
#              linewidth = 6, label = 'GP Reza Post')
# ---------------------
# plt.errorbar(target, deltaSNRMeanALL.iloc[5,:], np.sqrt(deltaSNRVarALL.iloc[1,:]),
#              solid_capstyle = 'butt', capsize=8,
#              linewidth = 6, label = 'GP Prio R')
# plt.errorbar(target, deltaSNRMeanALL.iloc[4,:], np.sqrt(deltaSNRVarALL.iloc[0,:]),
#              solid_capstyle = 'butt', capsize=8,
#              linewidth = 6, label = 'GP Post R')
# ---------------------
plt.yticks([-25, -20, -15, -10, -5, 0, 5, 10, 15, 20])
# plt.xticks([-10, -5, 0, 5, 10, 15, 20, 25, 30, 35])
plt.legend(fontsize=28, loc="lower left", ncol=3)
plt.xticks(fontsize=28, rotation=0)
plt.yticks(fontsize=28, rotation=0)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["bottom"].set_visible(True)
ax.spines["left"].set_visible(False)
fig.tight_layout()
plt.savefig("../FigsGP/" + fig_name + ".eps", format="eps", bbox_inches="tight")
plt.savefig("../FigsGP/" + fig_name + ".png", format="png", bbox_inches="tight")
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
GPFiltSigsPostDFRep2.shape

# %%
fig_name = "SNRComparison"
target = [-10, -5, 0, 5, 10, 15, 20, 25, 30, 35]
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(18, 8))
plt.grid()
plt.xlabel("Input SNR [dB]", fontsize=28)
plt.ylabel("SNR improvement [dB]", fontsize=28)
# ---------------------
plt.errorbar(
    target,
    deltaSNRMeanALL.iloc[6, :],
    np.sqrt(deltaSNRVarALL.iloc[2, :]),
    solid_capstyle="butt",
    capsize=8,
    linewidth=6,
    label="Wavelet [benchmark]",
)
# ---------------------
# plt.errorbar(target, deltaSNRMeanALL.iloc[1,:], np.sqrt(deltaSNRVarALL.iloc[1,:]),
#              solid_capstyle = 'butt', capsize=8,
#              linewidth = 6, label = 'GP Prio ')
# plt.errorbar(target, deltaSNRMeanALL.iloc[0,:], np.sqrt(deltaSNRVarALL.iloc[0,:]),
#              solid_capstyle = 'butt', capsize=8,
#              linewidth = 6, label = 'GP Post')
# ---------------------
plt.errorbar(
    target,
    deltaSNRMeanALL.iloc[3, :],
    np.sqrt(deltaSNRVarALL.iloc[1, :]),
    solid_capstyle="butt",
    capsize=8,
    linewidth=6,
    label="GP Prio F",
)
plt.errorbar(
    target,
    deltaSNRMeanALL.iloc[2, :],
    np.sqrt(deltaSNRVarALL.iloc[0, :]),
    solid_capstyle="butt",
    capsize=8,
    linewidth=6,
    label="GP Post F",
)
# ---------------------
plt.errorbar(
    target,
    deltaSNRMeanALL.iloc[5, :],
    np.sqrt(deltaSNRVarALL.iloc[1, :]),
    solid_capstyle="butt",
    capsize=8,
    linewidth=6,
    label="GP Prio R",
)
plt.errorbar(
    target,
    deltaSNRMeanALL.iloc[4, :],
    np.sqrt(deltaSNRVarALL.iloc[0, :]),
    solid_capstyle="butt",
    capsize=8,
    linewidth=6,
    label="GP Post R",
)


# ---------------------
plt.yticks([-30, -25, -20, -15, -10, -5, 0, 5, 10, 15])
# plt.xticks([-10, -5, 0, 5, 10, 15, 20, 25, 30, 35])
plt.legend(fontsize=28, loc="lower left", ncol=3)
plt.xticks(fontsize=28, rotation=0)
plt.yticks(fontsize=28, rotation=0)
fig.tight_layout()
plt.savefig("../FigsGP/" + fig_name + ".eps", format="eps", bbox_inches="tight")
plt.savefig("../FigsGP/" + fig_name + ".png", format="png", bbox_inches="tight")
plt.show()

# %%
stop

# %%
deltaSNRRep3

# %%
GPFilteredDataDFRep1

# %%
GPFilteredSynDataDFRep1

# %%
col_names = deltaSNRRep3.columns[np.argsort(deltaSNRRep3.iloc[0, :])[:4]]

# %%
type(col_names)

# %%
index_no = df.columns.get_loc(col_names)

# %%
plt.plot(deltaSNRRep1.iloc[0, :])

# %%
plt.plot(deltaSNRRep2.iloc[0, :])

# %%
plt.plot(deltaSNRRep3.iloc[0, :])

# %%
# deltaSNRRep3.columns[np.argmin(deltaSNRRep3.iloc[0,:], axis=0)]
deltaSNRRep3.columns[np.argsort(deltaSNRRep3.iloc[0, :])[:4]]

# %%
i = 0
print(RawDataDF.columns[i])
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(18, 25))
# ---
plt.subplot(6, 1, 1)
plt.grid()
plt.plot(RawDataDF.iloc[:, i][0:3000], label="clean ecg [" + RawDataDF.columns[i] + "]")
plt.legend(fontsize=12, loc="upper right")
# ---
plt.subplot(6, 1, 2)
plt.grid()
plt.plot(NoiseDFRep1.iloc[:, i][0:3000], label="noise [" + RawDataDF.columns[i] + "]")
plt.legend(fontsize=12, loc="upper right")
# ---
plt.subplot(6, 1, 3)
plt.grid()
plt.plot(NoisyDataDFRep1.iloc[:, i][0:3000], label="ecg [" + RawDataDF.columns[i] + "]")
plt.legend(fontsize=12, loc="upper right")
# ---
plt.subplot(6, 1, 4)
plt.grid()
plt.plot(NoisyDataDFRep1.iloc[:, 0][0:3000], label="ecg [" + RawDataDF.columns[i] + "]")
plt.plot(
    GPProxyDataDFRep1.iloc[:, i][0:3000],
    label="proxy GP [" + RawDataDF.columns[i] + "]",
)
plt.legend(fontsize=12, loc="upper right")
# ---
plt.subplot(6, 1, 5)
plt.grid()
plt.plot(NoisyDataDFRep1.iloc[:, 0][0:3000], label="ecg [" + RawDataDF.columns[i] + "]")
plt.plot(
    GPFilteredDataDFRep1.iloc[:, i][0:3000],
    label="filter GP [" + RawDataDF.columns[i] + "]",
)
plt.legend(fontsize=12, loc="upper right")
plt.subplot(6, 1, 6)
plt.grid()
plt.plot(NoisyDataDFRep1.iloc[:, 0][0:3000], label="ecg [" + RawDataDF.columns[i] + "]")
plt.plot(
    WaveFilteredDataDFRep1.iloc[:, i][0:3000],
    label="filter GP [" + RawDataDF.columns[i] + "]",
)
plt.legend(fontsize=12, loc="upper right")

# %%
i = 0

DiffGPProxy = GPProxyDataDFRep1.iloc[:, 0] - RawDataDF.iloc[:, i]
DiffGPFiltered = GPFilteredDataDFRep1.iloc[:, i] - RawDataDF.iloc[:, i]
DiffWaveFiltered = WaveFilteredDataDFRep1.iloc[:, i] - RawDataDF.iloc[:, i]

print(RawDataDF.columns[i])
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(18, 15))
# ---
plt.subplot(3, 1, 1)
plt.grid()
plt.plot(DiffGPProxy[0:3000], label="ecg [" + RawDataDF.columns[i] + "]")
plt.legend(fontsize=12, loc="upper right")
# ---
plt.subplot(3, 1, 2)
plt.grid()
plt.plot(DiffGPFiltered[0:3000], label="filter GP [" + RawDataDF.columns[i] + "]")
plt.legend(fontsize=12, loc="upper right")
# ---
plt.subplot(3, 1, 3)
plt.grid()
plt.plot(DiffWaveFiltered[0:3000], label="filter GP [" + RawDataDF.columns[i] + "]")
plt.legend(fontsize=12, loc="upper right")

# %%
print(np.linalg.norm(DiffGPProxy[0:3000]))
print(np.linalg.norm(DiffGPFiltered[0:3000]))
print(np.linalg.norm(DiffWaveFiltered[0:3000]))

# %%
DiffGPProxy

# %%
RawDataDF.shape[1]

# %%
from ComputeInputOutputDeltaSNRs import ComputeInputOutputDeltaSNRs

# -------------------------------------
deltaSNRRep1 = pd.DataFrame()
for i in np.arange(RawDataDF.shape[1]):
    deltaSNRproxyGP = ComputeInputOutputDeltaSNRs(
        RawDataDF.iloc[:, i].dropna(),
        NoiseDFRep1.iloc[:, i].dropna(),
        GPProxyDataDFRep1.iloc[:, i].dropna(),
    )[2]
    deltaSNRfilterGP = ComputeInputOutputDeltaSNRs(
        RawDataDF.iloc[:, i].dropna(),
        NoiseDFRep1.iloc[:, i].dropna(),
        GPFilteredDataDFRep1.iloc[:, i].dropna(),
    )[2]
    deltaSNRRep1[RawDataDF.columns[i]] = [deltaSNRproxyGP, deltaSNRfilterGP]
# -------------------------------------
deltaSNRRep2 = pd.DataFrame()
for i in np.arange(RawDataDF.shape[1]):
    deltaSNRproxyGP = ComputeInputOutputDeltaSNRs(
        RawDataDF.iloc[:, i].dropna(),
        NoiseDFRep2.iloc[:, i].dropna(),
        GPProxyDataDFRep2.iloc[:, i].dropna(),
    )[2]
    deltaSNRfilterGP = ComputeInputOutputDeltaSNRs(
        RawDataDF.iloc[:, i].dropna(),
        NoiseDFRep2.iloc[:, i].dropna(),
        GPFilteredDataDFRep2.iloc[:, i].dropna(),
    )[2]
    deltaSNRRep2[RawDataDF.columns[i]] = [deltaSNRproxyGP, deltaSNRfilterGP]
# -------------------------------------
deltaSNRRep3 = pd.DataFrame()
for i in np.arange(RawDataDF.shape[1]):
    deltaSNRproxyGP = ComputeInputOutputDeltaSNRs(
        RawDataDF.iloc[:, i].dropna(),
        NoiseDFRep3.iloc[:, i].dropna(),
        GPProxyDataDFRep3.iloc[:, i].dropna(),
    )[2]
    deltaSNRfilterGP = ComputeInputOutputDeltaSNRs(
        RawDataDF.iloc[:, i].dropna(),
        NoiseDFRep3.iloc[:, i].dropna(),
        GPFilteredDataDFRep3.iloc[:, i].dropna(),
    )[2]
    deltaSNRRep3[RawDataDF.columns[i]] = [deltaSNRproxyGP, deltaSNRfilterGP]
# -------------------------------------
deltaSNRRep4 = pd.DataFrame()
for i in np.arange(RawDataDF.shape[1]):
    deltaSNRproxyGP = ComputeInputOutputDeltaSNRs(
        RawDataDF.iloc[:, i].dropna(),
        NoiseDFRep4.iloc[:, i].dropna(),
        GPProxyDataDFRep4.iloc[:, i].dropna(),
    )[2]
    deltaSNRfilterGP = ComputeInputOutputDeltaSNRs(
        RawDataDF.iloc[:, i].dropna(),
        NoiseDFRep4.iloc[:, i].dropna(),
        GPFilteredDataDFRep4.iloc[:, i].dropna(),
    )[2]
    deltaSNRRep4[RawDataDF.columns[i]] = [deltaSNRproxyGP, deltaSNRfilterGP]
# -------------------------------------
deltaSNRRep5 = pd.DataFrame()
for i in np.arange(RawDataDF.shape[1]):
    deltaSNRproxyGP = ComputeInputOutputDeltaSNRs(
        RawDataDF.iloc[:, i].dropna(),
        NoiseDFRep5.iloc[:, i].dropna(),
        GPProxyDataDFRep5.iloc[:, i].dropna(),
    )[2]
    deltaSNRfilterGP = ComputeInputOutputDeltaSNRs(
        RawDataDF.iloc[:, i].dropna(),
        NoiseDFRep5.iloc[:, i].dropna(),
        GPFilteredDataDFRep5.iloc[:, i].dropna(),
    )[2]
    deltaSNRRep5[RawDataDF.columns[i]] = [deltaSNRproxyGP, deltaSNRfilterGP]
# -------------------------------------
deltaSNR = (
    deltaSNRRep1 + deltaSNRRep2 + deltaSNRRep3 + deltaSNRRep4 + deltaSNRRep5
) / 5
deltaSNR.index = ["proxyGP", "filterGP"]

deltaSNRMean = pd.DataFrame(deltaSNR.mean(axis=1), columns={"SNR" + noise_level})
deltaSNRMean

# %%
csv_name = "WaveFilteredSignals" + str(noise_level) + "db_" + str(repetition)
WaveFilteredDataDFRep1 = pd.read_csv(
    os.getcwd() + "/../../../Results/" + csv_name + ".csv", header=None, index_col=None
)

WaveFilteredDataDFRep1

# %%
WaveFilteredDataDFRep1 = WaveFilteredDataDFRep1.where(
    pd.notnull(WaveFilteredDataDFRep1), None
)

# %%
WaveFilteredDataDFRep1
